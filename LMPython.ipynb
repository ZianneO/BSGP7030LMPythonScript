# %% [markdown]
# # Linear Modeling in Python

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
from sklearn.linear_model import LinearRegression

# %% [markdown]
# ## Reading in csv file

# %%
df = pd.read_csv("regrex1.csv")

# %%
df.head()
# Out:
#         y        x
# 0  6.8102   9.8492
# 1  9.8437  11.1450
# 2  4.9767   5.1209
# 3  5.0006   8.1085
# 4  3.5047   3.5599

# %%
df.head
# Out:
# <bound method NDFrame.head of           y        x
# 0    6.8102   9.8492
# 1    9.8437  11.1450
# 2    4.9767   5.1209
# 3    5.0006   8.1085
# 4    3.5047   3.5599
# 5    3.6419   1.9883
# 6    7.8725  15.5322
# 7    5.1442   7.5202
# 8    8.3883  14.0202
# 9    6.8204   7.5226
# 10   9.0185  14.3272
# 11   2.6148   3.8950
# 12   3.7367   1.8707
# 13   2.8651   0.8347
# 14  10.7469  18.3413
# 15   2.3710   1.6645
# 16   9.6653  17.0579
# 17   7.1926   9.2375
# 18  11.7833  21.0000
# 19   3.9537   3.5286
# 20  15.0000  25.0000
# 21   7.9152   9.9008
# 22   9.3368  17.5990
# 23   8.7587  13.8790
# 24   6.7813  10.8690
# 25   7.9924  12.6238
# 26   2.2806   0.9719
# 27  10.4050  14.4814
# 28   3.7891   2.1792
# 29  10.9067  18.4052>

# %% [markdown]
# # Data in Scatter Plot

# %%
plt.scatter(df['x'],df['y'])

# %% [markdown]
# # Linear Model

# %%
X= df[['x']]
y= df['y']

# %%
model = LinearRegression()
model.fit(X,y)
# Out:
# LinearRegression()

# %% [markdown]
# # Obtaining coefficients

# %%
r_sq = model.score(X,y)
print(f"Intercept: {model.intercept_}")
print(f"Coefficients (Slope): {model.coef_}")
# Out:
# Intercept: 2.2481427736669986
# Coefficients (Slope): [0.46906228]

# %%
print(f"Coefficient of Determination (R-squared): {r_sq}")
# Out:
# Coefficient of Determination (R-squared): 0.9293641551281743

# %%
y_pred = model.predict(df['x'])
# Out:
# /srv/conda/envs/notebook/lib/python3.9/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 y_pred = model.predict(df['x'])
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sklearn/linear_model/_base.py:306, in LinearModel.predict(self, X)
#     292 def predict(self, X):
#     293     """
#     294     Predict using the linear model.
#     295
#    (...)
#     304         Returns predicted values.
#     305     """
# --> 306     return self._decision_function(X)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sklearn/linear_model/_base.py:285, in LinearModel._decision_function(self, X)
#     282 def _decision_function(self, X):
#     283     check_is_fitted(self)
# --> 285     X = self._validate_data(X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     286     coef_ = self.coef_
#     287     if coef_.ndim == 1:
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sklearn/base.py:633, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, cast_to_ndarray, **check_params)
#     631         out = X, y
#     632 elif not no_val_X and no_val_y:
# --> 633     out = check_array(X, input_name="X", **check_params)
#     634 elif no_val_X and not no_val_y:
#     635     out = _check_y(y, **check_params)
#
# File /srv/conda/envs/notebook/lib/python3.9/site-packages/sklearn/utils/validation.py:1045, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#    1038         else:
#    1039             msg = (
#    1040                 f"Expected 2D array, got 1D array instead:\narray={array}.\n"
#    1041                 "Reshape your data either using array.reshape(-1, 1) if "
#    1042                 "your data has a single feature or array.reshape(1, -1) "
#    1043                 "if it contains a single sample."
#    1044             )
# -> 1045         raise ValueError(msg)
#    1047 if dtype_numeric and hasattr(array.dtype, "kind") and array.dtype.kind in "USV":
#    1048     raise ValueError(
#    1049         "dtype='numeric' is not compatible with arrays of bytes/strings."
#    1050         "Convert your data to numeric values explicitly instead."
#    1051     )
#
# ValueError: Expected a 2-dimensional container but got <class 'pandas.core.series.Series'> instead. Pass a DataFrame containing a single row (i.e. single sample) or a single column (i.e. single feature) instead.
